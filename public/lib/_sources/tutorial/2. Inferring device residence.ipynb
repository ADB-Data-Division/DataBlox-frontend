# %% [markdown]
# # Inferring device residence

# %% [markdown]
# Load the necessary libraries.

# %%
import os

import datablox_od
import geopandas as gpd
import pandas as pd
from tqdm.notebook import tqdm

pd.set_option("display.max_rows", 5)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Folder names

# %%
SAMPLE_OUTPUT_DIRECTORY = os.path.join("..", "sample_output")
RESIDENCE_DIRECTORY = os.path.join(SAMPLE_OUTPUT_DIRECTORY, "residence")
os.makedirs(RESIDENCE_DIRECTORY, exist_ok=True)

# %% [markdown]
# Load the Parquet file containing the pings (mapped to Thailand's administrative areas).
#
# To ensure data quality, we will consider only pings with horizontal accuracy less than 1 km ("accuracy" is a bit of a misnomer; a lower horizontal accuracy implies a lower radius of error).

# %%
pings = gpd.read_parquet(os.path.join(SAMPLE_OUTPUT_DIRECTORY, "pings.parquet"))

# The horizontal_accuracy column is in meters
pings = pings[pings["horizontal_accuracy"] < 1000]
pings
# Out:
#                                      device_id  horizontal_accuracy  \
# 0         AFBDE0F7-34DF-4B2B-9227-1FF9C45C1879                  3.0
# 1         AFBDE0F7-34DF-4B2B-9227-1FF9C45C1879                  3.0
# ...                                        ...                  ...
# 28897519  4CCB1986-85B2-42E6-987F-664A9D24EBA5                 16.0
# 28897520  4CCB1986-85B2-42E6-987F-664A9D24EBA5                 16.0
#
#                    timestamp                    geometry          h3_cell  \
# 0        2019-01-01 17:24:34  POINT (103.16413 14.72815)  8865981a25fffff
# 1        2019-01-01 09:04:29  POINT (102.06894 15.19989)  88659bba05fffff
# ...                      ...                         ...              ...
# 28897519 2020-01-01 04:09:37  POINT (100.45427 13.89577)  8864a4aa49fffff
# 28897520 2019-12-31 21:53:39  POINT (100.45433 13.89558)  8864a4aa49fffff
#
#                     ADM1_EN                     ADM2_EN  \
# 0                  Buri Ram     Buri Ram#Phlapphla Chai
# 1         Nakhon Ratchasima  Nakhon Ratchasima#Non Thai
# ...                     ...                         ...
# 28897519         Nonthaburi         Nonthaburi#Pak Kret
# 28897520         Nonthaburi         Nonthaburi#Pak Kret
#
#                                       ADM3_EN
# 0               Buri Ram#Phlapphla Chai#Sadao
# 1         Nakhon Ratchasima#Non Thai#Non Thai
# ...                                       ...
# 28897519           Nonthaburi#Pak Kret#Tha It
# 28897520           Nonthaburi#Pak Kret#Tha It
#
# [27394704 rows x 8 columns]

# %% [markdown]
# ```{note}
# The code below has the ``include_statistics`` parameter of ``datablox_od.residence.infer_residence()`` set to ``True``. Hence, the resulting data frames include statistics on the number of days each device issued nighttime pings and the number of nighttime pings from the inferred residence for every month in the observation window, among others. However, turning on this option can significantly increase the runtime and memory consumption.
#
# If you need to speed up the runtime or reduce memory consumption, consider setting ``include_statistics`` to ``False`` (which is the default).
# ```

# %% [markdown]
# Infer device residence for each month in the period June 2019 to December 2019.

# %%
year_of_interest = 2019
for month_of_interest in tqdm(range(6, 13)):
    residence = datablox_od.residence.infer_residence(
        pings,
        device_id_column="device_id",
        timestamp_column="timestamp",
        area_column="ADM2_EN",
        year=year_of_interest,
        month=month_of_interest,
        start_time="19:00",
        end_time="07:00",
        num_months_in_observation_window=6,
        min_fraction_pings_in_residence=0.5,
        min_num_days_present=30,
        include_statistics=True,
        delete_temp_dir=False,
        n_jobs=-1,
        verbose=False,
    )

    residence.to_parquet(
        os.path.join(
            RESIDENCE_DIRECTORY,
            f"{year_of_interest}-{month_of_interest:02}.parquet",
        )
    )
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# As an example, display the device residence information for June 2019.

# %%
pd.read_parquet(
    os.path.join(
        RESIDENCE_DIRECTORY,
        f"2019-06.parquet",
    )
)
# Out:
#                                                    residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834         Lamphun#Mae Tha
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301        Songkhla#Hat Yai
# ...                                                      ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD  Kalasin#Mueang Kalasin
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF     Bangkok#Bangkok Noi
#
#                                       2019-01_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                         1
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                        13
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                        13
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                        14
#
#                                       2019-02_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                         5
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                        25
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                        15
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                         3
#
#                                       2019-03_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                         8
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                        15
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                         7
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                         3
#
#                                       2019-04_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                         3
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                         8
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                        10
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                        13
#
#                                       2019-05_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                         7
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                         8
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                        10
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                        12
#
#                                       2019-06_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                        20
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                         5
# ...                                                        ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                         8
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                        20
#
#                                       total_num_days_present  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                      44
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                      74
# ...                                                      ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                      63
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                      65
#
#                                       2019-01_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                               1
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                             357
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              47
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                              35
#
#                                       2019-02_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                              10
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                            1141
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              39
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                               9
#
#                                       2019-03_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                              20
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                             193
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              18
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                               9
#
#                                       2019-04_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                              19
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                              40
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              40
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                              73
#
#                                       2019-05_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                             106
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                              30
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              61
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                              78
#
#                                       2019-06_num_pings_in_residence  \
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                             135
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                               0
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                              15
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                             112
#
#                                       fraction_of_pings_in_residence
# device_id
# 00068053-F5A7-41BE-BE5D-972516D41834                        0.970000
# 0016B09E-B2C4-4E14-BF85-8FD84EBEE301                        0.974543
# ...                                                              ...
# FFCD4F7D-FBFB-42AF-8EB9-2227A02CB6FD                        0.960699
# FFF3C0F8-41CB-4715-A7E9-18CB811791EF                        0.747045
#
# [2435 rows x 15 columns]
