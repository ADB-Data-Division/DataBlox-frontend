# %% [markdown]
# # Luxury tourism

# %% [markdown]
# ```{admonition} Disclaimer
# :class: warning
#
# This case study is a preliminary exploration intended only to illustrate a possible use case of DataBlox-OD. The insights presented here are derived from a limited subset of our GPS data and should not be considered conclusive of actual trends.
#
# The views expressed here are those of the authors and do not necessarily reflect the views and policies of the Asian Development Bank (ADB) or its Board of Governors or the governments they represent.
# ```

# %% [markdown]
# Load the necessary libraries.

# %%
import os

import geopandas as gpd
import numpy as np
import pandas as pd

import _luxury_tourism_util as util

pd.set_option("diWsplay.max_rows", 5)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Folder names

# %%
SAMPLE_DATA_DIRECTORY = os.path.join("..", "sample_data")
SAMPLE_OUTPUT_DIRECTORY = os.path.join("..", "sample_output")
CASE_STUDY_DATA_DIRECTORY = os.path.join("..", "case_study_data")
CASE_STUDY_OUTPUT_DIRECTORY = os.path.join("..", "case_study_output")

BOUNDARIES_DIRECTORY = os.path.join(SAMPLE_DATA_DIRECTORY, "boundaries")
TOURISM_DIRECTORY = os.path.join(SAMPLE_DATA_DIRECTORY, "tourism")
STAYPOINTS_DIRECTORY = os.path.join(SAMPLE_OUTPUT_DIRECTORY, "tourism", "staypoints")
ANNOTATED_TOURISM_TRIPS_DIRECTORY = os.path.join(
    SAMPLE_OUTPUT_DIRECTORY, "tourism", "annotated_tourism_trips"
)
RELATIVE_WEALTH_ANNOTATED_TOURISM_TRIPS_DIRECTORY = os.path.join(
    CASE_STUDY_OUTPUT_DIRECTORY, "relative_wealth_annotated_tourism_trips"
)
LUXURY_TOURISM_TRIPS_DIRECTORY = os.path.join(
    CASE_STUDY_OUTPUT_DIRECTORY, "luxury_tourism_trips"
)

os.makedirs(RELATIVE_WEALTH_ANNOTATED_TOURISM_TRIPS_DIRECTORY, exist_ok=True)
os.makedirs(LUXURY_TOURISM_TRIPS_DIRECTORY, exist_ok=True)

# %% [markdown]
# Administrative boundaries of Thailand

# %%
adm1 = gpd.read_file(os.path.join(BOUNDARIES_DIRECTORY, "thailand_adm1.geojson"))
adm3 = gpd.read_file(os.path.join(BOUNDARIES_DIRECTORY, "thailand_adm3.geojson"))

# %% [markdown]
# <hr>

# %% [markdown]
# ## I. Data preparation

# %% [markdown]
# We start by annotating the visitors' staypoints with their relative wealth based on Meta's [relative wealth index map](https://www.pnas.org/doi/10.1073/pnas.2113658119), which has a spatial resolution of 1 km.

# %%
util.annotate_staypoints_with_relative_wealth(
    ANNOTATED_TOURISM_TRIPS_DIRECTORY,
    RELATIVE_WEALTH_ANNOTATED_TOURISM_TRIPS_DIRECTORY,
    os.path.join(CASE_STUDY_DATA_DIRECTORY, "tha_relative_wealth_index.csv"),
)

# %% [markdown]
# Filter the visitors to include only luxury visitors &mdash; those who visited a place with relative wealth in the 99.9<sup>th</sup> percentile.

# %%
util.identify_trips_with_visit_to_wealthy_area(
    RELATIVE_WEALTH_ANNOTATED_TOURISM_TRIPS_DIRECTORY, LUXURY_TOURISM_TRIPS_DIRECTORY
)

# %% [markdown]
# From the previous tutorials, the visitors' staypoints have already been annotated with nearby main tourist attractions, transportation hubs, accommodation, and food and beverage establishments. Here we add additional annotations to broaden the range of points of interest and include boat storages, exhibition centers, malls, and nightlife activity spots, among others.

# %%
util.annotate_tourism_trips_with_addl_points_of_interest(
    LUXURY_TOURISM_TRIPS_DIRECTORY,
    points_of_interest=util.process_openstreetmap(
        os.path.join(
            SAMPLE_DATA_DIRECTORY,
            "tourism",
            "openstreetmap",
            "hotosm_tha_points_of_interest_polygons_geojson.geojson",
        )
    ),
)

# %% [markdown]
# <hr>

# %% [markdown]
# ## II. Illustrating trips of luxury visitors

# %% [markdown]
# ```{admonition} Disclaimer
# :class: warning
#
# This case study includes names of commercial establishments only for purposes of discussion and illustration. Their inclusion does not in any way imply endorsement by ADB or its affiliates.
# ```

# %% [markdown]
# To illustrate trips of luxury visitors, we consider two trips made by device ID `1BC36F71-7A9F-42A3-A2AC-F1282680C4E6`.

# %%
luxury_tourism = gpd.read_parquet(
    os.path.join(
        LUXURY_TOURISM_TRIPS_DIRECTORY, "1BC36F71-7A9F-42A3-A2AC-F1282680C4E6.parquet"
    )
)

# %% [markdown]
# ### October 2024 trip: Two-night stay in Phuket with excursions to Phangnga

# %%
luxury_tourism.loc[51]
# Out:
#                 time_arrive         time_depart  num_pings_in_staypoint  \
# trip_id
# 51      2024-10-08 05:38:45 2024-10-08 06:41:22                       3
# 51      2024-10-08 07:38:22 2024-10-08 10:20:46                       9
# ...                     ...                 ...                     ...
# 51      2024-10-10 13:33:19 2024-10-10 14:55:57                      17
# 51      2024-10-10 17:22:20 2024-10-10 22:37:50                      16
#
#          num_minutes_stayed                    geometry  \
# trip_id
# 51                62.616667   POINT (99.02519 18.78633)
# 51               162.400000    POINT (98.30577 8.10085)
# ...                     ...                         ...
# 51                82.633333  POINT (100.75101 13.68968)
# 51               315.500000   POINT (99.02506 18.78658)
#
#                                     device_id          h3_cell       ADM1_EN  \
# trip_id
# 51       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  886482c613fffff    Chiang Mai
# 51       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  886422c251fffff        Phuket
# ...                                       ...              ...           ...
# 51       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  8864a495adfffff  Samut Prakan
# 51       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  886482c613fffff    Chiang Mai
#
#                               ADM2_EN  \
# trip_id
# 51       Chiang Mai#Mueang Chiang Mai
# 51                     Phuket#Thalang
# ...                               ...
# 51             Samut Prakan#Bang Phli
# 51       Chiang Mai#Mueang Chiang Mai
#
#                                              ADM3_EN  ...  \
# trip_id                                               ...
# 51       Chiang Mai#Mueang Chiang Mai#Nong Pa Khrang  ...
# 51                              Phuket#Thalang#Sakhu  ...
# ...                                              ...  ...
# 51                  Samut Prakan#Bang Phli#Nong Prue  ...
# 51       Chiang Mai#Mueang Chiang Mai#Nong Pa Khrang  ...
#
#                         nearby_food_and_beverages_names_en  \
# trip_id
# 51       [Café Amazon, None, None, Shewe Cafe, Kuai Tia...
# 51       [None, None, None, None, None, None, None, Non...
# ...                                                    ...
# 51                                                  [None]
# 51       [Café Amazon, None, None, Shewe Cafe, Kuai Tia...
#
#                         nearby_food_and_beverages_names_th  \
# trip_id
# 51       [คาเฟ่ อเมซอน, None, None, None, ก๋วยเตี่ยวเนื...
# 51       [None, None, None, None, None, None, None, Non...
# ...                                                    ...
# 51                                                  [None]
# 51       [คาเฟ่ อเมซอน, None, None, None, ก๋วยเตี่ยวเนื...
#
#                            nearby_food_and_beverages_types    rwi  \
# trip_id
# 51       [cafe, cafe, cafe, cafe, restaurant, restauran...  1.333
# 51       [fast_food, restaurant, restaurant, restaurant...  0.720
# ...                                                    ...    ...
# 51                                                  [None]  1.071
# 51       [cafe, cafe, cafe, cafe, restaurant, restauran...  1.333
#
#         score_percentile nearby_addl_points_of_interest_osm_ids  \
# trip_id
# 51             99.532696                          [122605036.0]
# 51             92.019832                                  [nan]
# ...                  ...                                    ...
# 51             98.134535                                  [nan]
# 51             99.532696                          [122605036.0]
#
#         nearby_addl_points_of_interest_names  \
# trip_id
# 51           [ศูนยทรัพยากรการเรียนรูสิรินธร]
# 51                                    [None]
# ...                                      ...
# 51                                    [None]
# 51           [ศูนยทรัพยากรการเรียนรูสิรินธร]
#
#         nearby_addl_points_of_interest_names_en  \
# trip_id
# 51       [Sirindhorn Learning Resources Center]
# 51                                       [None]
# ...                                         ...
# 51                                       [None]
# 51       [Sirindhorn Learning Resources Center]
#
#         nearby_addl_points_of_interest_names_th  \
# trip_id
# 51                                       [None]
# 51                                       [None]
# ...                                         ...
# 51                                       [None]
# 51                                       [None]
#
#         nearby_addl_points_of_interest_types
# trip_id
# 51                                 [library]
# 51                                    [None]
# ...                                      ...
# 51                                    [None]
# 51                                 [library]
#
# [19 rows x 48 columns]

# %% [markdown]
# **Day 1**
# - Morning:
#     - The time between their last ping from their district of residence (Mueang Chiang Mai, Chiang Mai) to their first ping from Phuket is roughly an hour, suggesting that they arrived by plane. This is also supported by the fact that their first ping is close to Phuket International Airport.
#     - Up until noon, they stayed in Thalang, Phuket, close to some boutique and luxury resort hotels (e.g., The Slate, which is among [2024 Tatler Best Asia 100 Hotels](https://www.tatlerasia.com/places/the-slate-phuket)).
#
# - Afternoon:
#     - They made a three-hour excursion to Takua Pa, Phangnga.
#
# - Night:
#     - They spent roughly an hour in Mueang Phuket, Phuket, close to cultural tourist attractions such as Bang Niew Shrine and Phuket Thai Hua Museum.
#     - Most of their evening was spent in Kathu, Phuket, close to Kalim Beach, a couple of nightclubs, and some fine dining restaurants (e.g., L'Arôme by the Sea, which is listed in the [MICHELIN Guide](https://guide.michelin.com/en/phuket-region/phuket/restaurant/l-arome-by-the-sea)).

# %% [markdown]
# **Day 2**
# - Morning to afternoon:
#     - They went on an excursion to Thai Mueang, Phangnga, from 8 a.m. to 6 p.m. Their staypoints are close to the Love Andamar Pier and the Chulabhorn Marine Park Conservatory Centre.
# - Night:
#     - Similar to the previous night, they spent over an hour in Mueang Phuket, Phuket, but, this time, close to Chalong Bay (Ao Chalong), diving centers, and yacht clubs.
#     - Again, most of their evening was spent in Kathu, Phuket, close to Kalim Beach, a couple of nightclubs, and some fine dining restaurants (e.g., L'Arôme by the Sea, which is listed in the [MICHELIN Guide](https://guide.michelin.com/en/phuket-region/phuket/restaurant/l-arome-by-the-sea)).

# %% [markdown]
# **Day 3**
# - Morning:
#     - They spent over an hour and a half in Mueang Phuket, Phuket, close to cultural tourist attractions such as Bang Niew Shrine and Phuket Thai Hua Museum.
#     - Their last ping from Phuket was recorded at around noon, close to Phuket International Airport.
# - Afternoon:
#     - They recorded a ping from Bang Phli, Samut Prakan, close to Suvarnabhumi Airport. It is possible that they took a connecting flight back to ther residence, and this is a layover.
#     - They arrived back in their district of residence (Mueang Chiang Mai, Chiang Mai).

# %% [markdown]
# Throughout their two-night trip, the following are the main tourist attractions in Phuket and Phangnga that they may have visited (main tourist attractions refer to those listed on the website of the Tourism Authority of Thailand):

# %%
places = util.identify_places_visited(
    "1BC36F71-7A9F-42A3-A2AC-F1282680C4E6",
    ["Phuket", "Phangnga"],
    LUXURY_TOURISM_TRIPS_DIRECTORY,
    os.path.join(TOURISM_DIRECTORY, "thailand_tourist_attractions.parquet"),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_sea_ports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_airports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY, "openstreetmap", "hotosm_tha_railways_lines_geojson.geojson"
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_points_of_interest_polygons_geojson.geojson",
    ),
    adm1,
    adm3,
)
util.plot_visited_places(
    places[
        places["category"].isin(
            ["Cultural", "Services", "Entertainment", "Nature", "seaport"]
        )
    ],
    zoom_start=11,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f2674de22962c9181a4ba18ed538021 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f2674de22962c9181a4ba18ed538021&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f2674de22962c9181a4ba18ed538021 = L.map(
#                 &quot;map_2f2674de22962c9181a4ba18ed538021&quot;,
#                 {
#                     center: [7.938241764705882, 98.36422411764705],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7818dc609dd2879dd4cd4a36f3f96605 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7818dc609dd2879dd4cd4a36f3f96605.addTo(map_2f2674de22962c9181a4ba18ed538021);
#
#
#             var marker_49a03e72699b379fd82c6103579abd5f = L.marker(
#                 [8.11695, 98.30738],
#                 {
# }
#             ).addTo(map_2f2674de22962c9181a4ba18ed538021);
#
#
#             var icon_05860e8655cd52f9b5bdd73a355896ed = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7382c4ad2ad55b03ea9bab0e17281e79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1621c4d3ac9422d526c72a3258af94c = $(`&lt;div id=&quot;html_c1621c4d3ac9422d526c72a3258af94c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Splash Jungle Water Parkin Phuket&lt;/div&gt;`)[0];
#                 popup_7382c4ad2ad55b03ea9bab0e17281e79.setContent(html_c1621c4d3ac9422d526c72a3258af94c);
#
#
#
#         marker_49a03e72699b379fd82c6103579abd5f.bindPopup(popup_7382c4ad2ad55b03ea9bab0e17281e79)
#         ;
#
#
#
#
#             marker_49a03e72699b379fd82c6103579abd5f.bindTooltip(
#                 `&lt;div&gt;
#                      Splash Jungle Water Parkin Phuket
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_49a03e72699b379fd82c6103579abd5f.setIcon(icon_05860e8655cd52f9b5bdd73a355896ed);
#
#
#             var marker_387eb01178fc54f6165f00bd0c11cbea = L.marker(
#                 [7.91283, 98.29416],
#                 {
# }
#             ).addTo(map_2f2674de22962c9181a4ba18ed538021);
#
#
#             var icon_275211acc4f1aca5fb40f3708f38f8d8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cbc9a7e1406a5f4c2111ce04a20104fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30f103c4e38dd0b8d0b3be173345144a = $(`&lt;div id=&quot;html_30f103c4e38dd0b8d0b3be173345144a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kalim Beach&lt;/div&gt;`)[0];
#                 popup_cbc9a7e1406a5f4c2111ce04a20104fd.setContent(html_30f103c4e38dd0b8d0b3be173345144a);
#
#
#
#         marker_387eb01178fc54f6165f00bd0c11cbea.bindPopup(popup_cbc9a7e1406a5f4c2111ce04a20104fd)
#         ;
#
#
#
#
#             marker_387eb01178fc54f6165f00bd0c11cbea.bindTooltip(
#                 `&lt;div&gt;
#                      Kalim Beach
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_387eb01178fc54f6165f00bd0c11cbea.setIcon(icon_275211acc4f1aca5fb40f3708f38f8d8);
#
#
#             var marker_f2bdaa83712012ca9afacff197fed29b = L.marker(
#                 [7.87558, 98.39411],
#                 {
# }
#             ).addTo(map_2f2674de22962c9181a4ba18ed538021);
#
#
#             var icon_979b2ff7e78e5e82077609d6f09aa3b7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;landmark&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_15037cbab55ad92963d09580673c8b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4762

# %% [markdown]
# ### November 2024 trip: Overnight nature trip to Rayong followed by overnight urban trip to Bangkok

# %%
luxury_tourism.loc[63]
# Out:
#                 time_arrive         time_depart  num_pings_in_staypoint  \
# trip_id
# 63      2024-11-11 19:09:56 2024-11-12 06:56:11                      13
# 63      2024-11-13 07:08:08 2024-11-13 08:39:22                       9
# ...                     ...                 ...                     ...
# 63      2024-11-15 11:59:54 2024-11-15 13:03:19                       4
# 63      2024-11-15 15:32:57 2024-11-15 17:25:06                      11
#
#          num_minutes_stayed                    geometry  \
# trip_id
# 63               706.250000    POINT (99.0251 18.78636)
# 63                91.233333  POINT (101.27472 12.72576)
# ...                     ...                         ...
# 63                63.416667  POINT (100.75543 13.69044)
# 63               112.150000   POINT (99.02508 18.78607)
#
#                                     device_id          h3_cell       ADM1_EN  \
# trip_id
# 63       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  886482c613fffff    Chiang Mai
# 63       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  8865884d1bfffff        Rayong
# ...                                       ...              ...           ...
# 63       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  8864a495adfffff  Samut Prakan
# 63       1BC36F71-7A9F-42A3-A2AC-F1282680C4E6  886482c613fffff    Chiang Mai
#
#                               ADM2_EN  \
# trip_id
# 63       Chiang Mai#Mueang Chiang Mai
# 63               Rayong#Mueang Rayong
# ...                               ...
# 63             Samut Prakan#Bang Phli
# 63       Chiang Mai#Mueang Chiang Mai
#
#                                              ADM3_EN  ...  \
# trip_id                                               ...
# 63       Chiang Mai#Mueang Chiang Mai#Nong Pa Khrang  ...
# 63                     Rayong#Mueang Rayong#Nam Khok  ...
# ...                                              ...  ...
# 63                  Samut Prakan#Bang Phli#Nong Prue  ...
# 63       Chiang Mai#Mueang Chiang Mai#Nong Pa Khrang  ...
#
#                         nearby_food_and_beverages_names_en  \
# trip_id
# 63       [Café Amazon, None, None, Shewe Cafe, Kuai Tia...
# 63                                                  [None]
# ...                                                    ...
# 63                                                  [None]
# 63       [Café Amazon, None, None, Shewe Cafe, Kuai Tia...
#
#                         nearby_food_and_beverages_names_th  \
# trip_id
# 63       [คาเฟ่ อเมซอน, None, None, None, ก๋วยเตี่ยวเนื...
# 63                                                  [None]
# ...                                                    ...
# 63                                                  [None]
# 63       [คาเฟ่ อเมซอน, None, None, None, ก๋วยเตี่ยวเนื...
#
#                            nearby_food_and_beverages_types    rwi  \
# trip_id
# 63       [cafe, cafe, cafe, cafe, restaurant, restauran...  1.333
# 63                                                  [None]  0.913
# ...                                                    ...    ...
# 63                                                  [None]  1.071
# 63       [cafe, cafe, cafe, cafe, restaurant, restauran...  1.333
#
#         score_percentile nearby_addl_points_of_interest_osm_ids  \
# trip_id
# 63             99.532696                          [122605036.0]
# 63             96.252569                                  [nan]
# ...                  ...                                    ...
# 63             98.134535                                  [nan]
# 63             99.532696                          [122605036.0]
#
#         nearby_addl_points_of_interest_names  \
# trip_id
# 63           [ศูนยทรัพยากรการเรียนรูสิรินธร]
# 63                                    [None]
# ...                                      ...
# 63                                    [None]
# 63           [ศูนยทรัพยากรการเรียนรูสิรินธร]
#
#         nearby_addl_points_of_interest_names_en  \
# trip_id
# 63       [Sirindhorn Learning Resources Center]
# 63                                       [None]
# ...                                         ...
# 63                                       [None]
# 63       [Sirindhorn Learning Resources Center]
#
#         nearby_addl_points_of_interest_names_th  \
# trip_id
# 63                                       [None]
# 63                                       [None]
# ...                                         ...
# 63                                       [None]
# 63                                       [None]
#
#         nearby_addl_points_of_interest_types
# trip_id
# 63                                 [library]
# 63                                    [None]
# ...                                      ...
# 63                                    [None]
# 63                                 [library]
#
# [16 rows x 48 columns]

# %% [markdown]
# **Day 1**
# - Morning:
#     - They arrived in Mueang Rayong, Rayong, at around 7:00 a.m.
# - Afternoon to evening:
#     - From afternoon to evening, they remained in Mueang Rayong, Rayong, but moved to staypoints in the subdistrict of Phe that are closer to nature tourist attractions such as Ao Wong Dean, Ao Tubtim, and Ko Samet. They spent roughly 11 hours in this area, which is located on the gulf coast of Eastern Thailand.
#
# **Day 2**
# - Morning:
#     - They moved to the subdistrict of Choeng Noen, still in Mueang Rayong, Rayong.
# - Afternoon:
#     - They arrived in Ratchathewi, Bangkok, and briefly stayed there for around 40 minutes, most likely to check in to their accommodation. Nearby food and beverage establishments include a notably wide range of restaurants serving international cuisine, along with biergartens and nightclubs. OpenStreetMap also records over a hundred hotels within the 2-km radius, including luxury hotels (e.g., Sheraton Grande Sukhumvit).
# - Night:
#     - Most of their evening was evenly spent between Pathum Wan and Vadhana, Bangkok, close to cultural attractions (e.g., Erawan Shrine), shopping centers (e.g., Siam Paragon, one of the largest malls in Thailand), galleries (e.g., Madame Tussauds Bangkok), and parks (e.g., Lumpini Park).
#     - For the remainder of the night, they stayed in Ratchathewi, Bangkok, at roughly the same staypoint where they arrived that afternoon. This supports the earlier inference of their accommodation likely being located in this area.
#
# **Day 3**
# - Morning:
#     - They stayed in the same staypoint where they were the previous night.
# - Afternoon:
#     - At noon, they recorded a ping from Bang Phli, Samut Prakan, close to Suvarnabhumi Airport. It is possible that they took a connecting flight back to ther residence, and this is a layover.
#     - They arrived back in their district of residence (Mueang Chiang Mai, Chiang Mai).

# %% [markdown]
# Throughout their overnight nature trip to Rayong, the following are the main tourist attractions that they may have visited:

# %%
places = util.identify_places_visited(
    "1BC36F71-7A9F-42A3-A2AC-F1282680C4E6",
    ["Rayong"],
    LUXURY_TOURISM_TRIPS_DIRECTORY,
    os.path.join(TOURISM_DIRECTORY, "thailand_tourist_attractions.parquet"),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_sea_ports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_airports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY, "openstreetmap", "hotosm_tha_railways_lines_geojson.geojson"
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_points_of_interest_polygons_geojson.geojson",
    ),
    adm1,
    adm3,
)
util.plot_visited_places(
    places[
        places["category"].isin(
            ["Cultural", "Services", "Entertainment", "Nature", "seaport"]
        )
    ],
    zoom_start=14,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_875cd6d0173d6867ae780de01d1b0946 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_875cd6d0173d6867ae780de01d1b0946&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_875cd6d0173d6867ae780de01d1b0946 = L.map(
#                 &quot;map_875cd6d0173d6867ae780de01d1b0946&quot;,
#                 {
#                     center: [12.561386666666666, 101.45330333333334],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c94eb068b046797771a8fc922dd39a92 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c94eb068b046797771a8fc922dd39a92.addTo(map_875cd6d0173d6867ae780de01d1b0946);
#
#
#             var marker_4e95e76723f23c8f32744597c06cbc67 = L.marker(
#                 [12.55423, 101.45081],
#                 {
# }
#             ).addTo(map_875cd6d0173d6867ae780de01d1b0946);
#
#
#             var icon_844538aa0d9b1464378d3c81c26fe9b7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3810726173c6de23cfaed0cd89a8ef60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed69205fdd5972a1f96d0b231c019a62 = $(`&lt;div id=&quot;html_ed69205fdd5972a1f96d0b231c019a62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ao Wong Dean&lt;/div&gt;`)[0];
#                 popup_3810726173c6de23cfaed0cd89a8ef60.setContent(html_ed69205fdd5972a1f96d0b231c019a62);
#
#
#
#         marker_4e95e76723f23c8f32744597c06cbc67.bindPopup(popup_3810726173c6de23cfaed0cd89a8ef60)
#         ;
#
#
#
#
#             marker_4e95e76723f23c8f32744597c06cbc67.bindTooltip(
#                 `&lt;div&gt;
#                      Ao Wong Dean
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4e95e76723f23c8f32744597c06cbc67.setIcon(icon_844538aa0d9b1464378d3c81c26fe9b7);
#
#
#             var marker_c4cdb677ad4d7bd4dca184c272d9ceb2 = L.marker(
#                 [12.5617, 101.45589],
#                 {
# }
#             ).addTo(map_875cd6d0173d6867ae780de01d1b0946);
#
#
#             var icon_639983af4c08077f2b085d864eff9ef3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7565f44ddcac8b7716dca4f6a2a24f2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_681b169d7815001ffa509a341ca5408e = $(`&lt;div id=&quot;html_681b169d7815001ffa509a341ca5408e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ao Tubtim&lt;/div&gt;`)[0];
#                 popup_7565f44ddcac8b7716dca4f6a2a24f2a.setContent(html_681b169d7815001ffa509a341ca5408e);
#
#
#
#         marker_c4cdb677ad4d7bd4dca184c272d9ceb2.bindPopup(popup_7565f44ddcac8b7716dca4f6a2a24f2a)
#         ;
#
#
#
#
#             marker_c4cdb677ad4d7bd4dca184c272d9ceb2.bindTooltip(
#                 `&lt;div&gt;
#                      Ao Tubtim
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c4cdb677ad4d7bd4dca184c272d9ceb2.setIcon(icon_639983af4c08077f2b085d864eff9ef3);
#
#
#             var marker_56a6347e2c98f8a3d26f4ea960c6d790 = L.marker(
#                 [12.56823, 101.45321],
#                 {
# }
#             ).addTo(map_875cd6d0173d6867ae780de01d1b0946);
#
#
#             var icon_a354d1feed0de70bcc34a7f89103a234 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_568c584ac4f9bc4e6367c5e41fc785ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37c48f01a7798b912ce0903d843feb3d = $(`&lt;div i

# %% [markdown]
# Throughout their overnight urban trip to Bangkok, the following are the main tourist attractions that they may have visited:

# %%
places = util.identify_places_visited(
    "1BC36F71-7A9F-42A3-A2AC-F1282680C4E6",
    ["Bangkok"],
    LUXURY_TOURISM_TRIPS_DIRECTORY,
    os.path.join(TOURISM_DIRECTORY, "thailand_tourist_attractions.parquet"),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_sea_ports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_airports_polygons_geojson.geojson",
    ),
    os.path.join(
        TOURISM_DIRECTORY, "openstreetmap", "hotosm_tha_railways_lines_geojson.geojson"
    ),
    os.path.join(
        TOURISM_DIRECTORY,
        "openstreetmap",
        "hotosm_tha_points_of_interest_polygons_geojson.geojson",
    ),
    adm1,
    adm3,
)
util.plot_visited_places(
    places[
        places["category"].isin(
            ["Cultural", "Services", "Entertainment", "Nature", "seaport"]
        )
    ],
    zoom_start=14,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01eed5c96409fe3002c808ef9021562b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01eed5c96409fe3002c808ef9021562b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01eed5c96409fe3002c808ef9021562b = L.map(
#                 &quot;map_01eed5c96409fe3002c808ef9021562b&quot;,
#                 {
#                     center: [13.745597037037037, 100.54201296296296],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdd6b1809bb55cae5b59faf963ce4e13 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdd6b1809bb55cae5b59faf963ce4e13.addTo(map_01eed5c96409fe3002c808ef9021562b);
#
#
#             var marker_8988f3a14e2e62d65be5d9b90f3f81b2 = L.marker(
#                 [13.7531, 100.5494],
#                 {
# }
#             ).addTo(map_01eed5c96409fe3002c808ef9021562b);
#
#
#             var icon_43ed5b09b65ad427126bf45c9921a214 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;landmark&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1e430a257f7c0894ea3a208a6f529d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9e58676c0e5b7d96bfa95a85ca826a7 = $(`&lt;div id=&quot;html_e9e58676c0e5b7d96bfa95a85ca826a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thai Labor Museum&lt;/div&gt;`)[0];
#                 popup_1e430a257f7c0894ea3a208a6f529d8e.setContent(html_e9e58676c0e5b7d96bfa95a85ca826a7);
#
#
#
#         marker_8988f3a14e2e62d65be5d9b90f3f81b2.bindPopup(popup_1e430a257f7c0894ea3a208a6f529d8e)
#         ;
#
#
#
#
#             marker_8988f3a14e2e62d65be5d9b90f3f81b2.bindTooltip(
#                 `&lt;div&gt;
#                      Thai Labor Museum
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8988f3a14e2e62d65be5d9b90f3f81b2.setIcon(icon_43ed5b09b65ad427126bf45c9921a214);
#
#
#             var marker_68b2bc1991dcb952ec3ab2899d93bf4a = L.marker(
#                 [13.75693, 100.56698],
#                 {
# }
#             ).addTo(map_01eed5c96409fe3002c808ef9021562b);
#
#
#             var icon_0d337ff37b4bc137b8115ea40744a833 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;store&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5a07248cb51a391440d4c49be41990c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_156d5a33d646d151f8f9cf85ffacc822 = $(`&lt;div id=&quot;html_156d5a33d646d151f8f9cf85ffacc822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jodd Fairs&lt;/div&gt;`)[0];
#                 popup_5a07248cb51a391440d4c49be41990c2.setContent(html_156d5a33d646d151f8f9cf85ffacc822);
#
#
#
#         marker_68b2bc1991dcb952ec3ab2899d93bf4a.bindPopup(popup_5a07248cb51a391440d4c49be41990c2)
#         ;
#
#
#
#
#             marker_68b2bc1991dcb952ec3ab2899d93bf4a.bindTooltip(
#                 `&lt;div&gt;
#                      Jodd Fairs
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_68b2bc1991dcb952ec3ab2899d93bf4a.setIcon(icon_0d337ff37b4bc137b8115ea40744a833);
#
#
#             var marker_ce3d853eb2f284bb12814efc8494c101 = L.marker(
#                 [13.76639, 100.56942],
#                 {
# }
#             ).addTo(map_01eed5c96409fe3002c808ef9021562b);
#
#
#             var icon_31da1d715b3944f84d4a583c60590186 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;cadetblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ticket-alt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b8918dbc3086bc85be01a62b11cafe11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f679ac464b2d06137126ce

# %% [markdown]
# <hr>

# %% [markdown]
# ## II. Profiling luxury visitors and their visits

# %% [markdown]
# Identify where most luxury visitors come from.

# %%
residences = util.profile_provinces_of_residence_of_visitors(
    LUXURY_TOURISM_TRIPS_DIRECTORY
)
for item in residences.most_common(5):
    print(
        f"{item[0]}:",
        item[1],
        f"({item[1] / sum(residences.values()) * 100}%)",
    )
# Out:
#   0%|          | 0/1202 [00:00<?, ?it/s]
# Bangkok: 345 (28.70216306156406%)
# Pathum Thani: 95 (7.903494176372712%)
# Nonthaburi: 61 (5.074875207986689%)
# Samut Prakan: 60 (4.9916805324459235%)
# Chon Buri: 51 (4.242928452579035%)

# %% [markdown]
# Investigate whether luxury trips are multi-destination trips or more focused at only one area.

# %%
util.profile_num_destination_of_trips(LUXURY_TOURISM_TRIPS_DIRECTORY)
# Out:
#   0%|          | 0/1202 [00:00<?, ?it/s]
# Province
# Mean: 1.9750415973377704
# Median: 2.0
# Min: 1
# Max: 11
# ===============
# District
# Mean: 3.509983361064892
# Median: 3.0
# Min: 1
# Max: 23

# %% [markdown]
# Identify which provinces are the most frequently visited in luxury trips, as well as the lengths of the visits.

# %%
profile_destination = util.profile_visited_provinces(LUXURY_TOURISM_TRIPS_DIRECTORY)
# Out:
#   0%|          | 0/1202 [00:00<?, ?it/s]

# %%
profile_destination.sort_values(("num_nights_stayed", "mean"), ascending=False).head(5)
# Out:
#         num_nights_stayed
#                     count      mean min max median
# ADM1_EN
# Trat                    1  2.000000   2   2    2.0
# Pattani                 4  1.750000   0   4    1.5
# Phayao                  7  1.571429   0  10    0.0
# Roi Et                 11  1.363636   0   6    1.0
# Phrae                  14  1.357143   0  10    0.0

# %%
profile_destination.sort_values(("num_nights_stayed", "count"), ascending=False).head(5)
# Out:
#              num_nights_stayed
#                          count      mean min max median
# ADM1_EN
# Bangkok                    716  0.687151   0  21    0.0
# Chon Buri                  208  0.485577   0   8    0.0
# Nonthaburi                 193  0.559585   0  32    0.0
# Pathum Thani               148  0.250000   0   6    0.0
# Samut Prakan               126  0.388889   0   9    0.0

# %% [markdown]
# `````{admonition} Insights
# :class: tip
# * Most luxury visitors come from Bangkok (29%), followed by Pathum Thani (8%).
# * On average, they visit 2 provinces or 4 districts per luxury trip.
# * The most visited luxury trip destination is Bangkok, followed by Chon Buri. However, visits there tend to be same-day trips (excursions).
# * The luxury trip destinations where visitors tend to stay the longest on average are Trat (2 nights) and Pattani (1.75 nights), both of which are coastal provinces bordering the Gulf of Thailand.
# `````
